# %% [markdown]
# <a href="https://colab.research.google.com/github/dewapramana222/struktur-data/blob/main/Tugas%201%20Dode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definisikan nilai mahasiswa untuk menyimpan angka
nilai_mahasiswa = []

# %%
for i in range(10):
  n = int(input(f"masukkan nilai mahasiswa ke-{i+1} :"))
  nilai_mahasiswa.append(n)
# Out:
# masukkan nilai mahasiswa ke-1 :60
# masukkan nilai mahasiswa ke-2 :50
# masukkan nilai mahasiswa ke-3 :70
# masukkan nilai mahasiswa ke-4 :60
# masukkan nilai mahasiswa ke-5 :80
# masukkan nilai mahasiswa ke-6 :40
# masukkan nilai mahasiswa ke-7 :80
# masukkan nilai mahasiswa ke-8 :70
# masukkan nilai mahasiswa ke-9 :60
# masukkan nilai mahasiswa ke-10 :90

# %%
# tampilakn nilai tertinggi dan terendah
print("Nilai mahasiswa:", nilai_mahasiswa)
print("Nilai Tertinggi:", max(nilai_mahasiswa))
print("Nilai Terendah:", min(nilai_mahasiswa))
# Out:
# Nilai mahasiswa: [60, 50, 70, 60, 80, 40, 80, 70, 60, 90]
# Nilai Tertinggi: 90
# Nilai Terendah: 40

# %%
import matplotlib.pyplot as plt

plt.figure()
kategori = ["Nilai Tertinggi", "Nilai Terendah"]
nilai_tertinggi = max(nilai_mahasiswa)
nilai_terendah = min(nilai_mahasiswa)
data = [nilai_tertinggi, nilai_terendah]

plt.bar(kategori, data, color=["blue", "yellow"])
plt.title("Grafik Nilai Tertinggi dan Terendah")
plt.ylabel("Jumlah Mahasiswa")
plt.ylim(0,100)
plt.show()

# %%
# hitung rata-rata
print("nilai_mahasiswa:", nilai_mahasiswa)
print("Rata-rata:", sum(nilai_mahasiswa)/len(nilai_mahasiswa))
# Out:
# nilai_mahasiswa: [60, 50, 70, 60, 80, 40, 80, 70, 60, 90]
# Rata-rata: 66.0

# %%
lulus = 0
tidak_lulus = 0

for n in nilai_mahasiswa:
    if n >= 60:
        lulus += 1
    else:
        tidak_lulus += 1

print("jumlah lulus :", lulus)
print("jumlah tidak lulus :", tidak_lulus)
# Out:
# jumlah lulus : 8
# jumlah tidak lulus : 2

# %%
import matplotlib.pyplot as plt

plt.figure()
kategori = ["Lulus", "Tidak Lulus"]
data = [lulus, tidak_lulus]

plt.bar(kategori, data, color=["green", "red"])
plt.title("Grafik Data Kelulusan Mahasiswa")
plt.ylabel("Jumlah Mahasiswa")
plt.ylim(0,10)
plt.show()

# %%
# Analisis Kompleksitas Program

print("Analisis Kompleksitas Program Nilai Mahasiswa\n")

print("1. Input nilai mahasiswa menggunakan perulangan for")
print("   Kompleksitas: O(n) karena perulangan berjalan sebanyak jumlah mahasiswa")

print("\n2. Menambahkan nilai ke dalam list menggunakan append()")
print("   Kompleksitas: O(1) karena hanya menambahkan satu elemen ke list")

print("\n3. Mencari nilai tertinggi dengan max()")
print("   Kompleksitas: O(n) karena memeriksa semua data")

print("\n4. Mencari nilai terendah dengan min()")
print("   Kompleksitas: O(n) karena memeriksa semua data")

print("\n5. Menghitung rata-rata")
print("   sum() -> O(n) karena menjumlahkan semua nilai")
print("   len() -> O(1) karena hanya menghitung jumlah elemen")

print("\n6. Menghitung jumlah lulus dan tidak lulus")
print("   Kompleksitas: O(n) karena memeriksa setiap nilai")

print("\n7. Membuat grafik dengan matplotlib")
print("   Kompleksitas: O(1) karena jumlah data yang ditampilkan sedikit")
# Out:
# Analisis Kompleksitas Program Nilai Mahasiswa
#
# 1. Input nilai mahasiswa menggunakan perulangan for
#    Kompleksitas: O(n) karena perulangan berjalan sebanyak jumlah mahasiswa
#
# 2. Menambahkan nilai ke dalam list menggunakan append()
#    Kompleksitas: O(1) karena hanya menambahkan satu elemen ke list
#
# 3. Mencari nilai tertinggi dengan max()
#    Kompleksitas: O(n) karena memeriksa semua data
#
# 4. Mencari nilai terendah dengan min()
#    Kompleksitas: O(n) karena memeriksa semua data
#
# 5. Menghitung rata-rata
#    sum() -> O(n) karena menjumlahkan semua nilai
#    len() -> O(1) karena hanya menghitung jumlah elemen
#
# 6. Menghitung jumlah lulus dan tidak lulus
#    Kompleksitas: O(n) karena memeriksa setiap nilai
#
# 7. Membuat grafik dengan matplotlib
#    Kompleksitas: O(1) karena jumlah data yang ditampilkan sedikit
