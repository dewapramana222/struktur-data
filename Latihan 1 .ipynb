# %% [markdown]
# <a href="https://colab.research.google.com/github/dewapramana222/struktur-data/blob/main/Latihan%201%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Buat list berisi nama 5 mahasiswa
mahasiswa = ["Didi", "Dode", "Dudu", "Dirga", "Ana"]
print("List nama mahasiswa:")
print(mahasiswa)
# Out:
# List nama mahasiswa:
# ['Didi', 'Dode', 'Dudu', 'Dirga', 'Ana']

# %%
# Tambahkan 1 nama baru menggunakan `.append()`.
mahasiswa.append("Boru")
print("\nSetelah menambahkan nama baru:")
print(mahasiswa)
# Out:
# Setelah menambahkan nama baru:
# ['Didi', 'Dode', 'Dudu', 'Dirga', 'Ana', 'Boru']

# %%
# Hapus satu elemen menggunakan `.remove()`.
mahasiswa.remove("Ana")
print("\nSetelah menghapus nama Ana:")
print(mahasiswa)
# Out:
# Setelah menghapus nama Ana:
# ['Didi', 'Dode', 'Dudu', 'Dirga', 'Boru']
