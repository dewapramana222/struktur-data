# %% [markdown]
# <a href="https://colab.research.google.com/github/dewapramana222/struktur-data/blob/main/Latihan%202%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# input 5 angka
list = []
for i in range(5):
    angka = int(input("Masukkan angka: "))
    list.append(angka)
# Out:
# Masukkan angka: 70
# Masukkan angka: 50
# Masukkan angka: 60
# Masukkan angka: 80
# Masukkan angka: 40

# %%
# tampilkan nilai maksimum, minimum, dan rata-rata
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [70, 50, 60, 80, 40]
# Nilai maksimum: 80
# Nilai minimum: 40
# Rata-rata: 60.0

# %%
#buat grafik batang menggunakan matplotlib
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
